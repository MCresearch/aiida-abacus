# %%
# %load_ext aiida
# %aiida
# Out:
# Loaded AiiDA DB environment - profile name: 2.0-dev.

# %%
import numpy as np
from aiida import engine, orm
from aiida.orm import Dict, KpointsData, StructureData, load_group
from aiida.tools import get_explicit_kpoints_path
from ase.build import bulk
from aiida_abacus.workflows.band import AbacusBandWorkChain

###
# set up code
computer = orm.load_computer("localhost")

# %%
builder = AbacusBandWorkChain.get_builder()
code = orm.load_code('abacus-3.10@localhost')
builder.base.abacus.code = code
builder.base.abacus.metadata.options = {
    "resources": {
        "num_machines": 1,
        "num_mpiprocs_per_machine": 1,  # use 1 cores per machine
    },
    "max_wallclock_seconds": 180,  # how long it can run before it should be killed
    # 'withmpi': False, # Set withmpi to False in case abacus was compiled without MPI support.
}

builder.structure = StructureData(ase=bulk("Si", "diamond", 5.43))
builder.base.kpoints_distance =orm.Float(0.3)
pseudo_family = load_group("PseudoDojo/0.4/PBE/SR/standard/upf")
builder.base.abacus.pseudos = pseudo_family.get_pseudos(structure=builder.structure)

# %%
builder.base.abacus.parameters = {
    'input':
    {# pseudo_dir will be set by the plugin based on the pseudos
    # 'symmetry': 1,
    "basis_type": "pw",
    "ecutwfc": 100,
    "scf_thr": 1e-4,  # 1e-7,
    # 'scf_nmax': 100,
    "device": "cpu",
    # 'ks_solver': 'dav_subspace',
    # 'precision': 'double',
    }
}
builder.band_settings = {'symprec': 0.1}

# %%
engine.run_get_node(builder)
# Out:
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_lattice']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_positions']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_types']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['number']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['transformation_matrix']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['international']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# 05/24/2025 12:17:06 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5660|AbacusBandWorkChain|run_scf]: launching AbacusBaseWorkChain<5669> for SCF
# 05/24/2025 12:17:06 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5669|AbacusBaseWorkChain|run_process]: launching AbacusCalculation<5675> iteration #1
# 05/24/2025 12:17:16 AM <43171> aiida.parser.AbacusParser: [WARNING] The following expected files are missing: ['OUT.aiida/device.log', 'OUT.aiida/STRU_ION_D', 'OUT.aiida/STRU_ION*_D']
# 05/24/2025 12:17:17 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5669|AbacusBaseWorkChain|results]: work chain completed after 1 iterations
# 05/24/2025 12:17:17 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5669|AbacusBaseWorkChain|on_terminated]: remote folders will not be cleaned
# 05/24/2025 12:17:18 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5682|AbacusBaseWorkChain|run_process]: launching AbacusCalculation<5685> iteration #1
# 05/24/2025 12:18:36 AM <43171> aiida.parser.AbacusParser: [WARNING] The following expected files are missing: ['OUT.aiida/device.log', 'OUT.aiida/STRU_ION_D', 'OUT.aiida/STRU_ION*_D']
# 05/24/2025 12:18:37 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5682|AbacusBaseWorkChain|results]: work chain completed after 1 iterations
# 05/24/2025 12:18:37 AM <43171> aiida.orm.nodes.process.workflow.workchain.WorkChainNode: [REPORT] [5682|AbacusBaseWorkChain|on_terminated]: remote folders will not be cleaned
# ResultAndNode(result={'primitive_structure': <StructureData: uuid: cfa05898-e239-4d35-84f8-58ff4d3c9512 (pk: 5665)>, 'seekpath_parameters': <Dict: uuid: 98a7f1b4-add8-40a5-957a-511a73d8cab5 (pk: 5663)>, 'band_structure': <BandsData: uuid: efa6477a-119f-4663-94c1-2da706c798bb (pk: 5688)>}, node=<WorkChainNode: uuid: 48712e79-b844-47f5-a18b-f2011c92441e (pk: 5660) (aiida_abacus.workflows.band.AbacusBandWorkChain)>)

# %%
load_node('efa6477a-119f-4663-94c1-2da706c798bb').show_mpl()

# %%
load_node(5675).outputs.misc.get_dict()
# Out:
# {'all_forces': [],
#  'all_stress': [],
#  'fermi_level': 6.4973046757,
#  'final_forces': None,
#  'final_stress': None,
#  'total_energy': '-230.2653914873930',
#  'number_of_bands': 14}
