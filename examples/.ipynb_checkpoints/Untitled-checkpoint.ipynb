# %%
# %load_ext aiida
# %aiida
# Out:
# Loaded AiiDA DB environment - profile name: 2.0-dev.

# %%
import numpy as np
from aiida import engine, orm
from aiida.orm import Dict, KpointsData, StructureData, load_group
from aiida.tools import get_explicit_kpoints_path
from ase.build import bulk

###
# set up code
computer = orm.load_computer("localhost")

# %%
code = load_code('abacus-3.10@localhost')
builder = code.get_builder()

builder.metadata.options = {
    "resources": {
        "num_machines": 1,
        "num_mpiprocs_per_machine": 1,  # use 1 cores per machine
    },
    "max_wallclock_seconds": 180,  # how long it can run before it should be killed
    # 'withmpi': False, # Set withmpi to False in case abacus was compiled without MPI support.
}

# %%
structure = StructureData(ase=bulk("Si", "fcc", 5.43))
seekpathout = get_explicit_kpoints_path(structure)
builder.structure = seekpathout['primitive_structure']
# Out:
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_lattice']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_positions']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['std_types']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['number']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['transformation_matrix']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(
# /home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/spglib/spglib.py:115: DeprecationWarning: dict interface (SpglibDataset['international']) is deprecated.Use attribute interface ({self.__class__.__name__}.{key}) instead
#   warnings.warn(

# %%
builder.kpoints = KpointsData()
builder.kpoints.set_kpoints_mesh([6, 6, 4], offset=[0.5, 0.5, 0.5])

# %%
pseudo_family = load_group("PseudoDojo/0.4/PBE/SR/standard/upf")
builder.pseudos = pseudo_family.get_pseudos(structure=structure)

# %%
builder.parameters = {
    'input':
    {# pseudo_dir will be set by the plugin based on the pseudos
    # 'symmetry': 1,
    "basis_type": "pw",
    "ecutwfc": 100,
    "scf_thr": 1e-4,  # 1e-7,
    # 'scf_nmax': 100,
    "device": "cpu",
    # 'ks_solver': 'dav_subspace',
    # 'precision': 'double',
    }
}

# %% [raw]
# results, node = engine.run.get_node(builder)

# %%
node = load_node(4090)

# %% [markdown]
# # NSCF

# %%
builder.parameters = {
    'input':
    {# pseudo_dir will be set by the plugin based on the pseudos
    # 'symmetry': 1,
    "basis_type": "pw",
    "ecutwfc": 100,
    "scf_thr": 1e-4,  # 1e-7,
    # 'scf_nmax': 100,
    "device": "cpu",
    # 'ks_solver': 'dav_subspace',
    # 'precision': 'double',
        'calculation': 'nscf',
    }
}

# %%
builder.kpoints = seekpathout['explicit_kpoints']
builder.settings = {
    'include_bands': True
}
builder.restart_folder = node.outputs.remote_folder

# %%
nscf_results, nscf_node = engine.run.get_node(builder)
# Out:
# 05/13/2025 03:34:22 PM <287453> aiida.broker.rabbitmq: [WARNING] RabbitMQ v3.12.1 is not supported and will cause unexpected problems!
# 05/13/2025 03:34:22 PM <287453> aiida.broker.rabbitmq: [WARNING] It can cause long-running workflows to crash and jobs to be submitted multiple times.
# 05/13/2025 03:34:22 PM <287453> aiida.broker.rabbitmq: [WARNING] See https://github.com/aiidateam/aiida-core/wiki/RabbitMQ-version-to-use for details.
# 05/13/2025 03:34:22 PM <287453> aiida.execmanager: [WARNING] [submission of calculation 4119] Unable to copy remote resource from /scratch/bonan/aiida/02/32/79c9-4b51-4a8c-81f8-e6c26e772f77/aiida to aiida! NOT Stopping but just ignoring!.
# to be retrieved: [['abacus_output', '.', 0], ['OUT.aiida/INPUT', '.', 2], ['OUT.aiida/kpoints', '.', 2], ['OUT.aiida/STRU.cif', '.', 2], ['OUT.aiida/device.log', '.', 2], ['OUT.aiida/warning.log', '.', 2], ['OUT.aiida/istate.info', '.', 2], ['OUT.aiida/running_nscf.log', '.', 2]]
# 05/13/2025 03:34:25 PM <287453> aiida.parser.AbacusParser: [WARNING] The following expected files are missing: ['OUT.aiida/kpoints', 'OUT.aiida/device.log', 'OUT.aiida/istate.info']
# 05/13/2025 03:34:25 PM <287453> aiida.orm.nodes.process.calculation.calcjob.CalcJobNode: [REPORT] [4119|AbacusCalculation|on_except]: Traceback (most recent call last):
#   File "/home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/plumpy/process_states.py", line 228, in execute
#     result = self.run_fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/processes/calcjobs/calcjob.py", line 710, in parse
#     exit_code_retrieved = self.parse_retrieved_output(retrieved_temporary_folder)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bonan/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/processes/calcjobs/calcjob.py", line 817, in parse_retrieved_output
#     exit_code = parser.parse(**parse_kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bonan/aiida_envs/aiida-2.0-dev/aiida-abacus/src/aiida_abacus/parsers/abacus.py", line 77, in parse
#     eigenvalues, occupations = parser.parse_eigenvalues()
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bonan/aiida_envs/aiida-2.0-dev/aiida-abacus/src/aiida_abacus/parsers/raw_parsers.py", line 119, in parse_eigenvalues
#     nspins = int(re.search(r"NSPIN == (\d)", self.content).group(1))
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 nscf_results, nscf_node = engine.run.get_node(builder)
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/launch.py:65, in run_get_node(process, inputs, **kwargs)
#      62 else:
#      63     runner = manager.get_manager().get_runner()
# ---> 65 return runner.run_get_node(process, inputs, **kwargs)
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/runners.py:291, in Runner.run_get_node(self, process, inputs, **kwargs)
#     280 def run_get_node(
#     281     self, process: TYPE_RUN_PROCESS, inputs: dict[str, Any] | None = None, **kwargs: Any
#     282 ) -> ResultAndNode:
#     283     """Run the process with the supplied inputs in this runner that will block until the process is completed.
#     284
#     285     The return value will be the results of the completed process
#    (...)
#     289     :return: tuple of the outputs of the process and the calculation node
#     290     """
# --> 291     result, node = self._run(process, inputs, **kwargs)
#     292     return ResultAndNode(result, node)
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/runners.py:261, in Runner._run(self, process, inputs, **kwargs)
#     259     signal.signal(signal.SIGINT, kill_process)
#     260     signal.signal(signal.SIGTERM, kill_process)
# --> 261     process_inited.execute()
#     262 finally:
#     263     signal.signal(signal.SIGINT, original_handler_int)
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/plumpy/processes.py:86, in ensure_not_closed.<locals>.func_wrapper(self, *args, **kwargs)
#      84 if self._closed:
#      85     raise exceptions.ClosedError('Process is closed')
# ---> 86 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/plumpy/processes.py:1197, in Process.execute(self)
#    1194 if not self.has_terminated():
#    1195     self.loop.run_until_complete(self.step_until_terminated())
# -> 1197 return self.future().result()
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/plumpy/process_states.py:228, in Running.execute(self)
#     226 try:
#     227     self._running = True
# --> 228     result = self.run_fn(*self.args, **self.kwargs)
#     229 finally:
#     230     self._running = False
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/processes/calcjobs/calcjob.py:710, in CalcJob.parse(self, retrieved_temporary_folder, existing_exit_code)
#     708 # Call the retrieved output parser
#     709 try:
# --> 710     exit_code_retrieved = self.parse_retrieved_output(retrieved_temporary_folder)
#     711 finally:
#     712     if retrieved_temporary_folder is not None:
#
# File ~/miniconda3/envs/aiida-2.4-dev/lib/python3.12/site-packages/aiida/engine/processes/calcjobs/calcjob.py:817, in CalcJob.parse_retrieved_output(self, retrieved_temporary_folder)
#     814 if retrieved_temporary_folder:
#     815     parse_kwargs['retrieved_temporary_folder'] = retrieved_temporary_folder
# --> 817 exit_code = parser.parse(**parse_kwargs)
#     819 for link_label, node in parser.outputs.items():
#     820     try:
#
# File ~/aiida_envs/aiida-2.0-dev/aiida-abacus/src/aiida_abacus/parsers/abacus.py:77, in AbacusParser.parse(self, **kwargs)
#      75 # Parse the bands output if requested
#      76 if self.check_include_node("bands"):
# ---> 77     eigenvalues, occupations = parser.parse_eigenvalues()
#      78     kpoints_log, weights_log = parser.parse_kpoints()
#      79     node = orm.BandsData()
#
# File ~/aiida_envs/aiida-2.0-dev/aiida-abacus/src/aiida_abacus/parsers/raw_parsers.py:119, in AbacusRawParser.parse_eigenvalues(self)
#     116 def parse_eigenvalues(self):
#     117     """Parse the eigenvalues"""
# --> 119     nspins = int(re.search(r"NSPIN == (\d)", self.content).group(1))
#     120     nkthis_procs = int(re.search(r"k-point number in this process = (\d+)", self.content).group(1))
#     121     parser = BlockParser(
#     122         self.lines,
#     123         re.compile(r"^ (\d+)/(\d+) kpoint \(Cartesian\) *= *([-0-9.]+) ([-0-9.]+) ([-0-9.]+)"),
#     124         offset=1,
#     125         types=[int, float, float],
#     126     )
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
nscf_results
